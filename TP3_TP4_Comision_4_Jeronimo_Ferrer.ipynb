# %% [markdown]
# <a href="https://colab.research.google.com/github/JeroFerrer93/python-ciencia-datos/blob/main/TP3_TP4_Comision_4_Jeronimo_Ferrer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TRABAJO PRACTICO N 3

# %% [markdown]
# ***TEMAS A DESARROLLAR:***
#
# Nociones de Probabilidad, simulación de procesos aleatorios, cálculo de parámetros estadisticos: Media o Valor Esperado(PROMEDIO), Mediana, Desvio Estandar. DISTRIBUCIONES DE PROABABILIDAD más frecuentes, por ejemplo la Normal.

# %% [markdown]
# ## Funciones estadísticas para análisis exploratorio de datos
# A continuación se presentan ejemplos de funciones estadísticas para el análisis exploratorio de datos utilizando NumPy:

# %% [markdown]
# #### Crear array aleatorio
# En esta celda, se utiliza la función np.random.rand() de NumPy para crear un array de números aleatorios con una forma específica. Luego, se imprime el array.

# %%
import numpy as np
random_array = np.random.randint(0,10, (4,3))
print("Array aleatorio:", random_array)
# Out:
# Array aleatorio: [[4 8 3]
#  [9 7 7]
#  [2 8 2]
#  [6 2 1]]

# %% [markdown]
# #### Media
# En esta celda, se crea un array 'array' y se utiliza la función np.mean() de NumPy para calcular la media del array. Luego, se imprime el resultado.

# %%
array = np.array([1, 2, 3, 4, 5])
media = np.mean(array)
print("Media:", media)
# Out:
# Media: 3.0

# %% [markdown]
# #### Desviación estándar
# En esta celda, se crea un array 'array' y se utiliza la función np.std() de NumPy para calcular la desviación estándar del array. Luego, se imprime el resultado.

# %%
array = np.array([1, 2, 3, 4, 5])
desviacion_estandar = np.std(array)
print("Desviación estándar:", desviacion_estandar)
# Out:
# Desviación estándar: 1.4142135623730951

# %% [markdown]
# #### Varianza
# La función np.var() se utiliza para calcular la varianza de un array.
# Ejemplo de uso:

# %%
array = np.array([1, 2, 3, 4, 5])
varianza = np.var(array)
print("Varianza:", varianza)
# Out:
# Varianza: 2.0

# %% [markdown]
# #### Valor mínimo
# En esta celda, se crea un array 'array' y se utiliza la función np.min() de NumPy para encontrar el valor mínimo del array. Luego, se imprime el resultado.

# %%
array = np.array([1, 2, 3, 4, 5])
matriz=np.random.randint(-3,3,(5,5))
#minimo = np.min(array)
minimo = np.min(matriz, axis=0)
print("Valor mínimo:", minimo)
print( matriz)
# Out:
# Valor mínimo: [-3 -2 -3  0 -3]
# [[-1  2 -3  2 -2]
#  [-1  2 -2  1  0]
#  [-1  2 -3  1  2]
#  [-3 -1 -2  0  2]
#  [-3 -2 -2  0 -3]]

# %% [markdown]
# #### Valor máximo
# En esta celda, se crea un array 'array' y se utiliza la función np.max() de NumPy para encontrar el valor máximo del array. Luego, se imprime el resultado.

# %%
maximo = np.max(array)
print("Valor máximo:", maximo)
# Out:
# Valor máximo: 5

# %% [markdown]
# #### Gráfico de dispersión
# En esta celda, se crea un array 'x' con valores aleatorios y un array 'y' con valores aleatorios. Luego, se utiliza la biblioteca Matplotlib para trazar un gráfico de dispersión con 'x' en el eje x y 'y' en el eje y. También se agrega etiquetas y un título al gráfico.

# %%
import matplotlib.pyplot as plt

x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico de dispersión')
plt.show()

# %% [markdown]
# En esta celda, se crea un array 'data' con valores aleatorios siguiendo una distribución normal. Luego, se utiliza la biblioteca Matplotlib para trazar un histograma de 'data'. También se agrega etiquetas y un título al gráfico.

# %%
data = np.random.normal(0, 1, 1000)

plt.hist(data, bins=30)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Histograma')
plt.show()

# %% [markdown]
# #### Mediana
# La función np.median() se utiliza para calcular la mediana de un array.
# Ejemplo de uso:

# %%
array = np.array([1, 2, 3, 4, 5])
mediana = np.median(array)
print("Mediana:", mediana)
# Out:
# Mediana: 3.0

# %% [markdown]
# #### Percentiles
# La función np.percentile() se utiliza para calcular los percentiles de un array.
# Ejemplo de uso:

# %%
array = np.array([1, 2, 3, 4, 5])
percentil_50 = np.percentile(array, 50)
print("Percentil 50:", percentil_50)
# Out:
# Percentil 50: 3.0

# %% [markdown]
# # EJEMPLOS Y APLICACIÓNES

# %% [markdown]
# ***APLICACIÓN DE PROBABILIDAD***
#
# Se Realiza el lanzamiento de un dado EQUILIBRADO JUSTO, de manera reiterada con las mismas condiciones, y se anotan sus resultados= CARA O CRUZ.
#
# Se le pide al usuario que defina la cantidad N de lanzamientos y se calcula su frecuencia relativa= 'PROBABILIDAD' de obtener cara o cruz. Se obtiene los siguientes resultados:

# %%
import numpy as np
n=int(input('ingrese la cantidad de simulación o lanzamientos: '))

#========= FORMA 1 DE SIMULAR LANZAMIENTO DE UN DADO============
dado=[]
cara=0
cruz=0
for i in range(n):
  dado.append(np.random.rand(1))
  dado1=np.array(dado)
  if dado1[i]<0.5:
    #print('salio cara')
    #print(dado[i])
    cara +=1
  else:
    #print('salio cruz')
    #print(dado[i])
    cruz +=1
# Out:
# ingrese la cantidad de simulación o lanzamientos: 22

# %%
#  mostrar la probailidad frecuencista de el lanzamiento de un dado
prom_cara=cara/n
prom_cruz=cruz/n
print('la probabilidad aproximada en '+str(n)+' lanzamientos de sacar CARA es:', prom_cara)
print('la probabilidad aproximada en '+str(n)+' lanzamientos de sacar CRUZ es:', prom_cruz)
# Out:
# la probabilidad aproximada en 22 lanzamientos de sacar CARA es: 0.6363636363636364
# la probabilidad aproximada en 22 lanzamientos de sacar CRUZ es: 0.36363636363636365

# %%
#========== FORMA COMPACTA DE SIMULAR USANDO NUMPY===========
m=int(input('ingrese la cantidad de simulación o lanzamientos: '))
lanzamientos = np.random.randint(0, 2, m)

# Calcular las probabilidades

probabilidad_cara = np.sum(lanzamientos ==0 ) / len(lanzamientos)
probabilidad_sello = np.sum(lanzamientos== 1) / len(lanzamientos)

print(f"Probabilidad de cara: {probabilidad_cara:.2f}")
print(f"Probabilidad de sello: {probabilidad_sello:.2f}")
# Out:
# ingrese la cantidad de simulación o lanzamientos: 50
# Probabilidad de cara: 0.52
# Probabilidad de sello: 0.48

# %%
import matplotlib.pyplot as plt
x=np.array(range(2))
y=np.array([probabilidad_cara, probabilidad_sello])

plt.bar(x,y)
plt.xlabel('Opción')
plt.ylabel('Frecuencia relativa')
plt.title('Histograma del lanzamiento de una moneda equilibrada')
plt.show()

# %% [markdown]
# # EJERCICIOS

# %% [markdown]
# ##***EJERCICIO 1***
#
# Simular el lanzamiento de un dado eqilibrado de 6 caras.
#
#
# *   Mostrar la probabilida aproximada de obtener el número 2, 3 y 5
# *   Graficar el histograma de las probabilidades

# %%
import numpy as np
import matplotlib.pyplot as plt

n_lanzamientos = int(input('ingrese la cantidad de simulación o lanzamientos: '))
lanzamientos = np.random.randint(1, 7, n_lanzamientos)  # Números entre 1 y 6 (6 caras del dado)

#probabilidades
probabilidad_2 = np.sum(lanzamientos == 2) / n_lanzamientos
probabilidad_3 = np.sum(lanzamientos == 3) / n_lanzamientos
probabilidad_5 = np.sum(lanzamientos == 5) / n_lanzamientos

print(f"Probabilidad de obtener el número 2: {probabilidad_2:.4f}")
print(f"Probabilidad de obtener el número 3: {probabilidad_3:.4f}")
print(f"Probabilidad de obtener el número 5: {probabilidad_5:.4f}")

# Graficar el histograma de las probabilidades
valores = [2, 3, 5]
probabilidades = [probabilidad_2, probabilidad_3, probabilidad_5]

plt.bar(valores, probabilidades)
plt.xlabel('Número en el dado')
plt.ylabel('Probabilidad')
plt.title('Histograma de probabilidades de obtener números en un dado equilibrado')
plt.xticks(valores)
plt.show()
# Out:
# ingrese la cantidad de simulación o lanzamientos: 50
# Probabilidad de obtener el número 2: 0.2000
# Probabilidad de obtener el número 3: 0.1000
# Probabilidad de obtener el número 5: 0.1400

# %% [markdown]
# ## EJERCICIO 4
#
# Dada la base de datos de ventas diarias durante una semana, de un negocio con 4 productos.- VER EJERCICIO PARTE 2 PRACTICO N 2- Realizar el siguiente análisis de datos para poder obtener información y planificar una estrategia de ventas.
#
#
# 1.   Calcular la media en la ventas por cada producto y la mediana. Plotear estos nuevos datos en un gráfico de barra.
# 2.    Calcular la media en la ventas por DÍA y la mediana. Plotear estos nuevos datos en un gráfico de TRAZO DE LINEAS.
# 3.   Realizar una conclusión en función las graficas y sugerir al menos 5 estrategias de venta o inversión de manera de potenciar este negocio.
# 4.   Calcular el desvio estandar de los datos por cada producto y concluir para cada producto como es su rango de variabilidad en las ventas de los mismos.Plotear los datos de ventas de la semana de los productos con mayor y menor desvio estandar y evidenciar la variabilidad indicada en el parametro *'DESVIO ESTANDAR'*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

producto_a = [20, 15, 25, 30, 18, 22, 24]
producto_b = [12, 20, 14, 8, 15, 18, 16]
producto_c = [35, 28, 32, 30, 26, 24, 30]
producto_d = [40, 38, 45, 42, 39, 41, 37]

venta_total = np.sum(producto_a) + np.sum(producto_b) + np.sum(producto_c) + np.sum(producto_d)
print("Venta total:", venta_total)

data = {
    'Producto': ['A', 'B', 'C', 'D'],
    'Ventas': [producto_a, producto_b, producto_c, producto_d]
}
df = pd.DataFrame(data)

# Calcular la media y mediana de ventas por producto
df['Media'] = df['Ventas'].apply(np.mean)
df['Mediana'] = df['Ventas'].apply(np.median)

df.plot(x='Producto', y=['Media', 'Mediana'], kind='bar')
plt.xlabel('Producto')
plt.ylabel('Ventas')
plt.xticks(rotation=0)
plt.title('Media y Mediana de Ventas por Producto')
plt.show()
# Out:
# Venta total: 744

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

producto_a = [20, 15, 25, 30, 18, 22, 24]
producto_b = [12, 20, 14, 8, 15, 18, 16]
producto_c = [35, 28, 32, 30, 26, 24, 30]
producto_d = [40, 38, 45, 42, 39, 41, 37]

data = {
    'Día': ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes', 'Sábado', 'Domingo'],
    'Producto_A': producto_a,
    'Producto_B': producto_b,
    'Producto_C': producto_c,
    'Producto_D': producto_d
}
df = pd.DataFrame(data)

df['Media'] = df[['Producto_A', 'Producto_B', 'Producto_C', 'Producto_D']].mean(axis=1)
df['Mediana'] = df[['Producto_A', 'Producto_B', 'Producto_C', 'Producto_D']].median(axis=1)

df.plot(x='Día', y=['Media', 'Mediana'], kind='line')
plt.xlabel('Día')
plt.ylabel('Ventas')
plt.title('Media y Mediana de Ventas por Día')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Realizar una conclusión en función las graficas y sugerir al menos 5 estrategias de venta o inversión de manera de potenciar este negocio.
#
# Por lo que vemos los productos con mas ventas son el C y el D, con unas Media y Mediana mas altas, por lo que tienen ventas mas estables.
# Analizando la media y mediana de las ventas por dias, podemos apreciar como sube a partir del martes, llegando a su pico el jueves y luego cae a su nivel mas bajo el viernes, volviendo a levantar levemente el fin de semana.
# Teniendo en cuenta estos datos, el foco principal de la empresa deberia ser aumentar el desarrollo de los productos C y D (aumento de costos), disminuir los demas (baja de costos). Y contratar mas personal o mover al personal para los dias entre martes y jueves inclusive que son los dias con mas ventas.
# Los demas dias si tenes muchos empleados, cambiarle los horarios a los dias que dijimos previamente. Simplemente tendrias mas empleados en momentos claves y menos en los dias con menos clientela, dejando tu plantilla de empleados inmovil.
#
#
# Otra cosa que se puede hacer es discontinuar los productos con menores ventas como el A y B para enfocarse en nuevos productos o en aumentar la produccion de los productos mas vendidos.

# %%
#desvío estándar de las ventas por producto
std_by_product = df[['Producto_A', 'Producto_B', 'Producto_C', 'Producto_D']].std()

#productos con mayor y menor desvío estándar
max_std_product = std_by_product.idxmax()
min_std_product = std_by_product.idxmin()

print("Desvío estándar por producto:")
print(std_by_product)

data_max_std = df[['Día', max_std_product]]
data_min_std = df[['Día', min_std_product]]

plt.plot(data_max_std['Día'], data_max_std[max_std_product], label=f'{max_std_product} - Mayor Desvío Estándar')
plt.plot(data_min_std['Día'], data_min_std[min_std_product], label=f'{min_std_product} - Menor Desvío Estándar')
plt.xlabel('Día')
plt.ylabel('Ventas')
plt.title('Variabilidad en Ventas de la Semana')
plt.legend()
plt.show()
# Out:
# Desvío estándar por producto:
# Producto_A    4.932883
# Producto_B    3.946065
# Producto_C    3.683942
# Producto_D    2.690371
# dtype: float64

# %% [markdown]
# ## EJERCICIO 5
#
# Solicitar al usuario que ingrese la cantidad N de datos a cargar. Luego generar de manera aleatoria los siguientes datos:
#
# * SEXO= 'MASCULINO', 'FEMENINO','NO ESPECIFICA'
# * EDAD= entre 28 y 60 años
# * ALTURA= entre un rango de 165.0 mts hasta 210 mts
# * PESO= entre un rango de 50  y 110 kg
# * HORAS DE DESCANSO diario= un número decimal
# * HORAS DE TRABAJO/ ESTUDIO diario= un número decimal
# * HORAS DE EJERCICIOS diario= un número decimal
#
# REalizar las siguientes indicaciones y extraer concluisiones sobre la información y la pooblación muestreada.
#
# 1.   Generar un array de dimensión 2 (matriz), con todos los datos ordenados, permitiendo visualizarlos como tabla.
# 2.   Suponiendo que la distribución de probabilidad de los datos muestrados de las N personas, se distribuyen en forma NORMAL. Encontrar la media en los datos de altura, peso, y horas de descanso, trabajo y ejercicios.
# 3.  Graficar la muestra o distribución de los datos  de pesos , y alturas en graficas separadas. Indicar el grado de variabilidad de sus datos
# 4.  Plotear de manera conjunta y encontrar si presentan correlación los datos de peso vs altura,
# 5. Plotear de manera conjunta los datos de horas de descanso, estudio y ejercicio

# %% [markdown]
# **Ayuda Como generar los datos**

# %%
import numpy as np
import matplotlib.pyplot as plt

def generar_datos(N):
    sexo = np.random.choice(['MASCULINO', 'FEMENINO', 'NO ESPECIFICA'], N ,[0.4, 0.5, 0.1])  # Por ejemplo, 40% masculino, 50% femenino, 10% no especificado)
    # Generar edades con distribución normal
    edad =np.random.normal(44, 6, N)
    edad=np.clip(np.around(edad),28,60)
    # Generar alturas, pesos y otras características
    altura = np.random.normal(180, 10, N)
    altura = np.clip(np.around(altura, decimals=1), 150.0, 210.0)

    peso = np.random.normal(80, 15, N)
    peso = np.clip(np.around(peso, decimals=1), 40.0, 130.0)

    horas_trabajo_estudio = np.random.normal(10, 2, N)
    horas_trabajo_estudio = np.clip(np.around(horas_trabajo_estudio, decimals=1), 4.0, 12.0)

    horas_ejercicio = np.random.normal(1, 0.5, N)
    horas_ejercicio = np.clip(np.around(horas_ejercicio, decimals=1), 0, 2)

    horas_descanso = 24 - horas_trabajo_estudio - horas_ejercicio
    datos = np.column_stack((sexo, edad, altura, peso, horas_descanso, horas_trabajo_estudio, horas_ejercicio))
    return datos


# Solicitar al usuario la cantidad N de datos a cargar
N = 1000

# Generar datos aleatorios para N personas con distribución normal y límites específicos
datos = generar_datos(N)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

N = int(input("Ingrese la cantidad de datos a cargar: "))

# Generar datos aleatorios
np.random.seed(42)  # Para reproducibilidad
sexo = np.random.choice(['MASCULINO', 'FEMENINO', 'NO ESPECIFICA'], size=N)
edad = np.random.randint(28, 61, size=N)
altura = np.random.uniform(165.0, 210.0, size=N)
peso = np.random.uniform(50, 110, size=N)
horas_descanso = np.random.uniform(4, 10, size=N)
horas_trabajo_estudio = np.random.uniform(4, 12, size=N)
horas_ejercicios = np.random.uniform(0, 3, size=N)

# matriz con los datos ordenados
data = np.array([sexo, edad, altura, peso, horas_descanso, horas_trabajo_estudio, horas_ejercicios]).T

# DataFrame para visualizar los datos como tabla
columns = ['Sexo', 'Edad', 'Altura', 'Peso', 'Horas Descanso', 'Horas Trabajo/Estudio', 'Horas Ejercicios']
df = pd.DataFrame(data, columns=columns)


media_altura = np.mean(altura)
media_peso = np.mean(peso)
media_horas_descanso = np.mean(horas_descanso)
media_horas_trabajo_estudio = np.mean(horas_trabajo_estudio)
media_horas_ejercicios = np.mean(horas_ejercicios)

print("Media de Altura:", media_altura)
print("Media de Peso:", media_peso)
print("Media de Horas de Descanso:", media_horas_descanso)
print("Media de Horas de Trabajo/Estudio:", media_horas_trabajo_estudio)
print("Media de Horas de Ejercicios:", media_horas_ejercicios)

# peso y altura en gráficos separados
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.hist(peso, bins=20, color='blue', edgecolor='black')
plt.xlabel('Peso')
plt.ylabel('Frecuencia')
plt.title('Distribución de Pesos')

plt.subplot(1, 2, 2)
plt.hist(altura, bins=20, color='green', edgecolor='black')
plt.xlabel('Altura')
plt.ylabel('Frecuencia')
plt.title('Distribución de Alturas')

plt.tight_layout()
plt.show()

# correlación entre peso y altura
plt.scatter(peso, altura)
plt.xlabel('Peso')
plt.ylabel('Altura')
plt.title('Correlación entre Peso y Altura')
plt.show()

# horas de descanso, estudio y ejercicio
plt.plot(horas_descanso, label='Descanso')
plt.plot(horas_trabajo_estudio, label='Trabajo/Estudio')
plt.plot(horas_ejercicios, label='Ejercicios')
plt.xlabel('Personas')
plt.ylabel('Horas')
plt.title('Horas de Descanso, Trabajo/Estudio y Ejercicios')
plt.legend()
plt.show()
# Out:
# Ingrese la cantidad de datos a cargar: 100
# Media de Altura: 189.58313965567987
# Media de Peso: 78.18871237942875
# Media de Horas de Descanso: 7.20124352169673
# Media de Horas de Trabajo/Estudio: 7.852837795091147
# Media de Horas de Ejercicios: 1.4365650314618335

# %% [markdown]
# # TRABAJO PRACTICO N 4

# %% [markdown]
# **Trabajo Practico Nº 4**
# Analisis sobre data set
#
# 1= Buscar los siguiente data set en la web
# * Titanic
# * Iris
# * Wine
# * Indian Diabetes
#
# 2- Explicar un data set , sus diferente Variables\
# 3- Deside justificando tu respuesta que tipo de categoria de variable son\
# 4- Detectar y arreglar los siguientes coceptos
# * Valores Ausente
# * Valores Atipicos
#
# 5- Sobre el dataset elegido , ¿se puede eliminar alguna fila o columna?\
#
# 6- Realizar analisis univariados
# * Grafico de frecuencia
# * Grafico de torta
# * Histograma
# * etc
#
# 7- En base a los graficos del punto 6 realizar distintas concluciones\
#
# 8- Realizar analisis de matriz corelacion y explicar que variable estan correlacionadas\
#
# PD Pueden Buscar data set de kaggle

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

iris = pd.read_csv('Iris.csv')
diabetes = pd.read_csv('diabetes.csv')
titanic = pd.read_csv('titanic.csv')
winequality_red = pd.read_csv('winequality_red.csv')

iris_variables = iris.columns
diabetes_variables = diabetes.columns
titanic_variables = titanic.columns
winequality_red_variables = winequality_red.columns


print(iris)
print(diabetes)
print(titanic)
print(winequality_red)


print(iris_variables)
print(diabetes_variables)
print(titanic_variables)
print(winequality_red_variables)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# Titanic Dataset:
#
# -PassengerId: Identificador único asignado a cada pasajero. Variable Numérica, ya que es un identificador único y tiene una naturaleza numérica, pero no es una variable que se use para cálculos numéricos.
#
# -Survived: Indica si el pasajero sobrevivió o no. Variable Categórica Binaria, ya que solo tiene dos categorías: 1 para sobrevivientes y 0 para no sobrevivientes.
#
# -Pclass: Clase del boleto. Variable Categórica Ordinal, ya que las clases tienen un orden específico: 1ra, 2da, 3ra.
#
# -Name: Nombre del pasajero. Variable de Texto, ya que contiene nombres en forma de texto.
#
# -Sex: Género del pasajero. Variable Categórica Nominal, ya que representa categorías sin un orden específico.
#
# -Age: Edad del pasajero. Variable Numérica Continua, ya que es un valor numérico que puede tomar cualquier valor en un rango continuo.
#
# -SibSp: Número de hermanos o cónyuges a bordo. Variable Numérica Discreta, ya que representa una cantidad entera de personas.
#
# -Parch: Número de padres o hijos a bordo. Variable Numérica Discreta, al igual que SibSp, representa una cantidad entera de personas.
#
# -Ticket: Número del boleto. Variable de Texto, ya que contiene números de boletos en forma de texto.
#
# -Fare: Tarifa del boleto. Variable Numérica Continua, ya que es un valor numérico que puede tener decimales.
#
# -Cabin: Número de cabina. Variable de Texto, ya que contiene números de cabina en forma de texto.
#
# -Embarked: Puerto de embarque. Variable Categórica Nominal, ya que representa categorías de puertos de embarque sin un orden específico.

# %%
titanic_missing = titanic.isnull()
print(titanic_missing)
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# 3    False  False     False
# 4    False   True     False
# ..     ...    ...       ...
# 886  False   True     False
# 887  False  False     False
# 888  False   True     False
# 889  False  False     False
# 890  False   True     False
#
# [891 rows x 12 columns]

# %%
titanic_cleaned = titanic.dropna()
print(titanic_cleaned)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 10       1   PP 9549  16.7000           G6        S
# 11       0    113783  26.5500         C103        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [183 rows x 12 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Grafico de frecuencia para la variable 'Pclass'
plt.figure(figsize=(8, 6))
titanic_cleaned['Pclass'].value_counts().plot(kind='bar')
plt.title('Frecuencia de Clases')
plt.xlabel('Clase')
plt.ylabel('Frecuencia')
plt.show()

# Grafico de torta para la variable 'Sex'
plt.figure(figsize=(8, 6))
titanic_cleaned['Sex'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('Distribución de Género')
plt.show()

# Histograma para la variable 'Age'
plt.figure(figsize=(8, 6))
plt.hist(titanic_cleaned['Age'].dropna(), bins=20, edgecolor='black')
plt.title('Histograma de Edades')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()

# Grafico de frecuencia para la variable 'Survived'
plt.figure(figsize=(8, 6))
titanic_cleaned['Survived'].value_counts().plot(kind='bar')
plt.title('Frecuencia de Sobrevivientes')
plt.xticks([0, 1], ['No sobrevivió', 'Sobrevivió'])
plt.xlabel('Sobrevivió')
plt.ylabel('Frecuencia')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

correlation_matrix = titanic_cleaned.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Matriz de Correlación')
plt.show()
# Out:
# <ipython-input-45-9732164a0cae>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = titanic_cleaned.corr()

# %% [markdown]
# Por lo que observo en el grafico de correlacion, la supervivencia estuvo mas correlacionada con la tarifa pagada por su ticket y si tenian familia a bordo o no. Por lo que quienes mas pagaron tuvieron mas posibilidades de sobrevivir junto a sus familiares, que quienes menos pagaron y no tenian familia.
# Por eso Jack no sobrevive en la peli...... era pobre y soltero.
